# %%
import pandas as pd

# %%
cursos = pd.read_csv("../data/Perfil_curso.csv", sep=';', encoding='latin-1')

# %%
cursos.head()
# Out:
#   COD_LINEA_NEGOCIO  COD_PRODUCTO          DESC_PRODUCTO  COD_CURRICULO  \
# 0                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 1                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 2                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 3                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 4                 U       3310004  INGENIERÍA INDUSTRIAL             42
#
#              DESC_CURRICULO COD_CURSO                          DESC_CURSO  \
# 0               201502 - LU     IN232  EX - INFORMÁTICA PARA LOS NEGOCIOS
# 1               201502 - LU     IN233          EX - DIRECCIÓN DE EMPRESAS
# 2               201502 - LU     IN234        EX - SISTEMAS DE INFORMACIÓN
# 3               201502 - LU      EF40      ECONOMÍA PARA LA GESTIÓN (ING)
# 4  201502 - LU(desactivada)      HU24              NIVELACIÓN DE LENGUAJE
#
#              DESC_ABRE_CURSO    clave COD_DIRECCION  ... 201902-43.4  \
# ...

# %%
cursos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 60 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   COD_LINEA_NEGOCIO       553 non-null    object
#  1   COD_PRODUCTO            553 non-null    int64
#  2   DESC_PRODUCTO           553 non-null    object
#  3   COD_CURRICULO           553 non-null    int64
#  4   DESC_CURRICULO          553 non-null    object
#  5   COD_CURSO               553 non-null    object
#  6   DESC_CURSO              553 non-null    object
#  7   DESC_ABRE_CURSO         553 non-null    object
#  8   clave                   553 non-null    object
#  9   COD_DIRECCION           553 non-null    object
#  10  NOM_DIRECCION           553 non-null    object
#  11  COD_CURSO_ELEC          553 non-null    object
#  12  CICLO                   553 non-null    int64
#  13  CANT_CREDITOS           553 non-null    int64
# ...

# %%
cursos.iloc[0]
# Out:
# COD_LINEA_NEGOCIO                                          U
# COD_PRODUCTO                                         3310004
# DESC_PRODUCTO                          INGENIERÍA INDUSTRIAL
# COD_CURRICULO                                             41
# DESC_CURRICULO                                   201502 - LU
# COD_CURSO                                              IN232
# DESC_CURSO                EX - INFORMÁTICA PARA LOS NEGOCIOS
# DESC_ABRE_CURSO                    EX - INFORM. PARA LOS NEG
# clave                                                41IN232
# COD_DIRECCION                                             IN
# NOM_DIRECCION                          INGENIERIA INDUSTRIAL
# COD_CURSO_ELEC                                      ELECTIVO
# CICLO                                                      9
# CANT_CREDITOS                                              3
# CANT_CREDEQUIV                                             0
# ...

# %%
cursos.iloc[10]
# Out:
# COD_LINEA_NEGOCIO                                U
# COD_PRODUCTO                               3310004
# DESC_PRODUCTO                INGENIERÍA INDUSTRIAL
# COD_CURRICULO                                   42
# DESC_CURRICULO            201502 - LU(desactivada)
# COD_CURSO                                    MA420
# DESC_CURSO                       MATEMÁTICA BÁSICA
# DESC_ABRE_CURSO                  MATEMÁTICA BÁSICA
# clave                                      42MA420
# COD_DIRECCION                                   MA
# NOM_DIRECCION                             CIENCIAS
# COD_CURSO_ELEC                         OBLIGATORIO
# CICLO                                            1
# CANT_CREDITOS                                    6
# CANT_CREDEQUIV                                   0
# FECHA_CREACION                           2/05/2016
# USUARIO_CREACION                          EDALVARE
# FECHA_MODIFICACION                      28/06/2018
# ...

# %%
cursos.COD_LINEA_NEGOCIO.value_counts()
# Out:
# U    553
# Name: COD_LINEA_NEGOCIO, dtype: int64

# %%
cursos.COD_CURRICULO.value_counts()
# Out:
# 45    123
# 43    123
# 44    112
# 41    112
# 42     83
# Name: COD_CURRICULO, dtype: int64

# %% [markdown]
# ## Pendientes
# - Obter todos los cursos por cada una de esas mallas

# %%
cursos.COD_CURSO.value_counts()
# Out:
# AD688    5
# IN231    5
# IN155    5
# HU187    5
# HU193    5
#         ..
# IN407    1
# IN332    1
# IN399    1
# IN406    1
# IN331    1
# Name: COD_CURSO, Length: 164, dtype: int64

# %%
cursos.COD_CURSO.value_counts().hist()

# %% [markdown]
# Cursos con el mismo codigo?

# %%
cursos.groupby(['COD_CURRICULO', 'COD_CURSO']).DESC_CURSO.agg([len])
# Out:
#                          len
# COD_CURRICULO COD_CURSO
# 41            AD185        1
#               AD687        1
#               AD688        1
#               AD689        1
#               AD690        1
# ...                      ...
# 45            TR224        1
#               TR240        1
#               TR281        1
#               TR282        1
#               TR285        1
#
# [553 rows x 1 columns]

# %%
curricula_cursos = cursos.groupby(['COD_CURRICULO'])

# %%
curricula_cursos.get_group((41))
# Out:
#     COD_LINEA_NEGOCIO  COD_PRODUCTO          DESC_PRODUCTO  COD_CURRICULO  \
# 0                   U       3310004  INGENIERÍA INDUSTRIAL             41
# 1                   U       3310004  INGENIERÍA INDUSTRIAL             41
# 2                   U       3310004  INGENIERÍA INDUSTRIAL             41
# 3                   U       3310004  INGENIERÍA INDUSTRIAL             41
# 19                  U       3310004  INGENIERÍA INDUSTRIAL             41
# ..                ...           ...                    ...            ...
# 190                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 313                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 314                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 315                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 316                 U       3310004  INGENIERÍA INDUSTRIAL             41
#
#     DESC_CURRICULO COD_CURSO                          DESC_CURSO  \
# ...

# %%
curricula_cursos.get_group((42))
# Out:
#     COD_LINEA_NEGOCIO  COD_PRODUCTO          DESC_PRODUCTO  COD_CURRICULO  \
# 4                   U       3310004  INGENIERÍA INDUSTRIAL             42
# 5                   U       3310004  INGENIERÍA INDUSTRIAL             42
# 6                   U       3310004  INGENIERÍA INDUSTRIAL             42
# 7                   U       3310004  INGENIERÍA INDUSTRIAL             42
# 8                   U       3310004  INGENIERÍA INDUSTRIAL             42
# ..                ...           ...                    ...            ...
# 84                  U       3310004  INGENIERÍA INDUSTRIAL             42
# 85                  U       3310004  INGENIERÍA INDUSTRIAL             42
# 86                  U       3310004  INGENIERÍA INDUSTRIAL             42
# 87                  U       3310004  INGENIERÍA INDUSTRIAL             42
# 318                 U       3310004  INGENIERÍA INDUSTRIAL             42
#
#                DESC_CURRICULO COD_CURSO  \
# ...

# %%
cursos.COD_CURSO_ELEC.value_counts()
# Out:
# ELECTIVO       311
# OBLIGATORIO    242
# Name: COD_CURSO_ELEC, dtype: int64

# %%
cursos.CICLO.value_counts()
# Out:
# 6     129
# 9     109
# 5      54
# 7      50
# 10     44
# 8      42
# 4      28
# 3      28
# 1      28
# 2      27
# 0      14
# Name: CICLO, dtype: int64

# %% [markdown]
# Porque hay tantos ciclos si solo tenemos 4 ciclos?

# %%
cursos.CANT_CREDITOS.value_counts()
# Out:
# 3    348
# 4     99
# 2     42
# 6     25
# 5     25
# 0     14
# Name: CANT_CREDITOS, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(cursos.CANT_CREDITOS)
# Out:
# (array([ 14.,   0.,   0.,  42.,   0., 348.,  99.,   0.,  25.,  25.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)

# %%
cursos[cursos['COD_CURSO'] == 'IN331']
# Out:
#     COD_LINEA_NEGOCIO  COD_PRODUCTO          DESC_PRODUCTO  COD_CURRICULO  \
# 296                 U       3310004  INGENIERÍA INDUSTRIAL             43
#
#                      DESC_CURRICULO COD_CURSO                   DESC_CURSO  \
# 296  Malla Nueva Ingresantes 201902     IN331  TALLER HERRAMIENTAS  LEAN 1
#
#                DESC_ABRE_CURSO    clave COD_DIRECCION  ... 201902-43.4  \
# 296  TALLER HERRAMIENTAS  LEAN  43IN331            IN  ...        #N/D
#
#     202001-44.4  202001-45.4  Total retiros  201901-41.5 201902-41.5  \
# 296        #N/D         #N/D           #N/D         #N/D        #N/D
#
#     201902-43.5 202001-44.5 202001-45.5  Total promedio de nota
# 296        #N/D        #N/D        #N/D                    #N/D
#
# [1 rows x 60 columns]

# %%
cursos[cursos['COD_CURSO'] == 'TR224']
# Out:
#     COD_LINEA_NEGOCIO  COD_PRODUCTO          DESC_PRODUCTO  COD_CURRICULO  \
# 186                 U       3310004  INGENIERÍA INDUSTRIAL             41
# 239                 U       3310004  INGENIERÍA INDUSTRIAL             43
# 435                 U       3310004  INGENIERÍA INDUSTRIAL             44
# 520                 U       3310004  INGENIERÍA INDUSTRIAL             45
#
#                       DESC_CURRICULO COD_CURSO        DESC_CURSO  \
# 186                      201502 - LU     TR224  FRANCÉS BÁSICO 1
# 239   Malla Nueva Ingresantes 201902     TR224  FRANCÉS BÁSICO 1
# 435                Curricula 2020-00     TR224  FRANCÉS BÁSICO 1
# 520  Curricula 2020-00 (Ingresantes)     TR224  FRANCÉS BÁSICO 1
#
#       DESC_ABRE_CURSO    clave COD_DIRECCION  ... 201902-43.4 202001-44.4  \
# 186  FRANCÉS BÁSICO 1  41TR224            TR  ...           0          10
# 239  FRANCÉS BÁSICO 1  43TR224            TR  ...           0          10
# ...

# %%
cursos[cursos['COD_CURSO'] == 'TR224'][cursos['COD_CURRICULO'] == 43]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     COD_LINEA_NEGOCIO  COD_PRODUCTO          DESC_PRODUCTO  COD_CURRICULO  \
# 239                 U       3310004  INGENIERÍA INDUSTRIAL             43
#
#                      DESC_CURRICULO COD_CURSO        DESC_CURSO  \
# 239  Malla Nueva Ingresantes 201902     TR224  FRANCÉS BÁSICO 1
#
#       DESC_ABRE_CURSO    clave COD_DIRECCION  ... 201902-43.4 202001-44.4  \
# 239  FRANCÉS BÁSICO 1  43TR224            TR  ...           0          10
#
#      202001-45.4  Total retiros  201901-41.5  201902-41.5 201902-43.5  \
# 239            0             22  14.36363636  14.63636364         NaN
#
#     202001-44.5 202001-45.5  Total promedio de nota
# 239       15.75         NaN             14.91666667
#
# [1 rows x 60 columns]

# %%
curso_target = cursos[cursos['COD_CURSO'] == 'TR224'][cursos['COD_CURRICULO'] == 43]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
curso_target
# Out:
#     COD_LINEA_NEGOCIO  COD_PRODUCTO          DESC_PRODUCTO  COD_CURRICULO  \
# 239                 U       3310004  INGENIERÍA INDUSTRIAL             43
#
#                      DESC_CURRICULO COD_CURSO        DESC_CURSO  \
# 239  Malla Nueva Ingresantes 201902     TR224  FRANCÉS BÁSICO 1
#
#       DESC_ABRE_CURSO    clave COD_DIRECCION  ... 201902-43.4 202001-44.4  \
# 239  FRANCÉS BÁSICO 1  43TR224            TR  ...           0          10
#
#      202001-45.4  Total retiros  201901-41.5  201902-41.5 201902-43.5  \
# 239            0             22  14.36363636  14.63636364         NaN
#
#     202001-44.5 202001-45.5  Total promedio de nota
# 239       15.75         NaN             14.91666667
#
# [1 rows x 60 columns]

# %%
curso_target.columns
# Out:
# Index(['COD_LINEA_NEGOCIO', 'COD_PRODUCTO', 'DESC_PRODUCTO', 'COD_CURRICULO',
#        'DESC_CURRICULO', 'COD_CURSO', 'DESC_CURSO', 'DESC_ABRE_CURSO', 'clave',
#        'COD_DIRECCION', 'NOM_DIRECCION', 'COD_CURSO_ELEC', 'CICLO',
#        'CANT_CREDITOS', 'CANT_CREDEQUIV', 'FECHA_CREACION', 'USUARIO_CREACION',
#        'FECHA_MODIFICACION', 'USUARIO_MODIFICACION', 'TOTAL CRED', '201901-41',
#        '201902-41', '201902-43', '202001-44', '202001-45', '202002-44',
#        '202002-45', 'Total de Habiles', '201901-41.1', '201902-41.1',
#        '201902-43.1', '202001-44.1', '202001-45.1', '202002-44.1',
#        '202002-45.1', 'Total de matriculados', '201901-41.2', '201902-41.2',
#        '201902-43.2', '202001-44.2', '202001-45.2', 'Total Aprueban',
#        '201901-41.3', '201902-41.3', '201902-43.3', '202001-44.3',
#        '202001-45.3', 'Total Desaprueban', '201901-41.4', '201902-41.4',
#        '201902-43.4', '202001-44.4', '202001-45.4', 'Total retiros',
# ...

# %%
curso_target[['TOTAL CRED', 
             'Total de Habiles', 
             'Total de matriculados', 
             'Total Aprueban',
             'Total Desaprueban', 
             'Total retiros',
             '201901-41.5', 
             '201902-41.5', 
             '201902-43.5', 
             '202001-44.5',
             '202001-45.5', 
             'Total promedio de nota']]
# Out:
#      TOTAL CRED Total de Habiles Total de matriculados Total Aprueban  \
# 239           3             4488                    99             30
#
#     Total Desaprueban Total retiros  201901-41.5  201902-41.5 201902-43.5  \
# 239                26            22  14.36363636  14.63636364         NaN
#
#     202001-44.5 202001-45.5 Total promedio de nota
# 239       15.75         NaN            14.91666667

# %% [markdown]
# Explicar esas colunas
